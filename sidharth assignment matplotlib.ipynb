# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize=(8,8))

f1 = plt.subplot2grid((5,6),(0,0),rowspan=1,colspan=3)
f2 = plt.subplot2grid((5,6),(0,3),rowspan=1,colspan=1)
f3 = plt.subplot2grid((5,6),(0,4),colspan=2)
f4 = plt.subplot2grid((5,6),(1,0),rowspan=3,colspan=1)
f5 = plt.subplot2grid((5,6),(1,1),colspan=2)
f6 = plt.subplot2grid((5,6),(1,3),colspan=3)
f7 = plt.subplot2grid((5,6),(2,1))
f8 = plt.subplot2grid((5,6),(2,2),rowspan=3,colspan=2)
f9 = plt.subplot2grid((5,6),(2,4),rowspan=3)
f10 = plt.subplot2grid((5,6),(2,5),rowspan=3)
f11 = plt.subplot2grid((5,6),(3,1))
f12 = plt.subplot2grid((5,6),(4,0),colspan=2)

plt.tight_layout()
plt.show()
